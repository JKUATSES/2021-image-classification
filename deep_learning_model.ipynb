# %% [markdown]
# <a href="https://colab.research.google.com/github/Ng-ethe/2021-image-classification/blob/main/deep_learning_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
# delete all files in the folder first of all
dir = '/content/drive/MyDrive/TB_classification_project/train_processed/normal/'
for f in os.listdir(dir):
    os.remove(os.path.join(dir, f))

# get file paths for all TB normal Xrays and copy the files into one folder

for k in range(len(normal_xray)):
    path= r"/content/drive/My Drive/TB_classification_project/train/normal/" + normal_xray[k] 
    # Reading the original image, here 1 implies that image is read as color
    image_c = cv2.imread(path, 1)

    
    # Converting the image to YCrCb
    image_yuv = cv2.cvtColor(image_c, cv2.COLOR_BGR2YUV)

    # Applying Histogram Equalization on the original imageof the Y channel
    image_yuv[:,:,0] = cv2.equalizeHist(image_yuv[:,:,0])

    # Convert the YUV image back to RGB format
    image_c_equalized = cv2.cvtColor(image_yuv, cv2.COLOR_YUV2BGR)

    #save file to drive
    directory = r'/content/drive/MyDrive/TB_classification_project/train_processed/normal/'
    os.chdir(directory)
    cv2.imwrite(normal_xray[k], image_c_equalized)

   

    #Plotting the Original and Histogram Equalized Image, Histogram and CDF for the first 5 images
    if k<=5:
        # Generating the histogram of the original image
        hist_c,bins_c = np.histogram(image_c.flatten(),256,[0,256])

        # Generating the cumulative distribution function of the original image
        cdf_c = hist_c.cumsum()
        cdf_c_normalized = cdf_c * hist_c.max()/ cdf_c.max()

         # Generating the histogram of the equalized image
        hist_c_equalized, bins_c_equalized = np.histogram(image_c_equalized.flatten(),256,[0,256])

        # Generating the cumulative distribution function of the original image
        cdf_c_equalized = hist_c_equalized.cumsum()
        cdf_c_equalized_normalized = cdf_c_equalized * hist_c_equalized.max()/ cdf_c_equalized.max()


        fig, axs = plt.subplots(2, 2)

        axs[0, 0].imshow(cv2.cvtColor(image_c, cv2.COLOR_BGR2RGB))
        axs[0, 0].axis('off')
        axs[0, 0].set_title('Original Image')

        axs[0, 1].imshow(cv2.cvtColor(image_c_equalized, cv2.COLOR_BGR2RGB))
        axs[0, 1].axis('off')
        axs[0, 1].set_title('Histogram Equalized Image')


        axs[1, 0].plot(cdf_c_normalized, color = 'b')
        axs[1, 0].hist(image_c.flatten(),256,[0,256], color = 'r')
        axs[1, 0].legend(('cdf','histogram'), loc = 'upper left')



        axs[1, 1].plot(cdf_c_equalized_normalized, color = 'b')
        axs[1, 1].hist(image_c_equalized.flatten(),256,[0,256], color = 'r')
        axs[1, 1].legend(('cdf_equalized','histogram_equalized'), loc = 'upper left')


        # Hide x labels and tick labels for top plots and y ticks for right plots.
        for ax in axs.flat:
            ax.label_outer()


   """

# %%
"""
# delete all files in the folder first of all
dir = '/content/drive/MyDrive/TB_classification_project/train_processed/TB/'
for f in os.listdir(dir):
    os.remove(os.path.join(dir, f))

# get file paths for all TB normal Xrays and copy the files into one folder

for k in range(len(TB_xray)):
    path= r"/content/drive/My Drive/TB_classification_project/train/TB/" + TB_xray[k] 
    # Reading the original image, here 1 implies that image is read as color
    image_c = cv2.imread(path, 1)

    

    # Converting the image to YCrCb
    image_yuv = cv2.cvtColor(image_c, cv2.COLOR_BGR2YUV)

    # Applying Histogram Equalization on the original imageof the Y channel
    image_yuv[:,:,0] = cv2.equalizeHist(image_yuv[:,:,0])

    # Convert the YUV image back to RGB format
    image_c_equalized = cv2.cvtColor(image_yuv, cv2.COLOR_YUV2BGR)

    #save file to drive
    directory = r'/content/drive/MyDrive/TB_classification_project/train_processed/TB/'
    os.chdir(directory)
    cv2.imwrite(normal_xray[k], image_c_equalized)



    #Plotting the Original and Histogram Equalized Image, Histogram and CDF for the first 5 images
    if k<=5:
        # Generating the histogram of the original image
        hist_c,bins_c = np.histogram(image_c.flatten(),256,[0,256])

        # Generating the cumulative distribution function of the original image
        cdf_c = hist_c.cumsum()
        cdf_c_normalized = cdf_c * hist_c.max()/ cdf_c.max()

        # Generating the histogram of the equalized image
        hist_c_equalized, bins_c_equalized = np.histogram(image_c_equalized.flatten(),256,[0,256])

        # Generating the cumulative distribution function of the original image
        cdf_c_equalized = hist_c_equalized.cumsum()
        cdf_c_equalized_normalized = cdf_c_equalized * hist_c_equalized.max()/ cdf_c_equalized.max()

        fig, axs = plt.subplots(2, 2)

        axs[0, 0].imshow(cv2.cvtColor(image_c, cv2.COLOR_BGR2RGB))
        axs[0, 0].axis('off')
        axs[0, 0].set_title('Original Image')

        axs[0, 1].imshow(cv2.cvtColor(image_c_equalized, cv2.COLOR_BGR2RGB))
        axs[0, 1].axis('off')
        axs[0, 1].set_title('Histogram Equalized Image')


        axs[1, 0].plot(cdf_c_normalized, color = 'b')
        axs[1, 0].hist(image_c.flatten(),256,[0,256], color = 'r')
        axs[1, 0].legend(('cdf','histogram'), loc = 'upper left')



        axs[1, 1].plot(cdf_c_equalized_normalized, color = 'b')
        axs[1, 1].hist(image_c_equalized.flatten(),256,[0,256], color = 'r')
        axs[1, 1].legend(('cdf_equalized','histogram_equalized'), loc = 'upper left')


        # Hide x labels and tick labels for top plots and y ticks for right plots.
        for ax in axs.flat:
            ax.label_outer()
    """

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from keras.preprocessing import image
import glob
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Dropout
import math
from keras.preprocessing import image
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.layers import Conv2D, Input, ZeroPadding2D,Dropout, BatchNormalization, Activation, MaxPooling2D, Flatten, Dense
from keras import models
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.callbacks import TensorBoard, ModelCheckpoint
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
from sklearn.utils import shuffle
import cv2
import sklearn

import numpy as np
import matplotlib.pyplot as plt
import time
import os

# %%
base_dir= "/content/drive/My Drive/TB_classification_project/train_processed/"
os.listdir(base_dir)
# Out:
# ['normal', 'TB']

# %%
normal_xray= os.listdir("/content/drive/My Drive/TB_classification_project/train/normal")
normal_xray[:5]
# Out:
# ['EHCFZYTF.png',
#  'VNVZJKOJ.png',
#  'BFUUQQNO.png',
#  'ZUQGJAOP.png',
#  'YPORVRYN.png']

# %%
TB_xray= os.listdir("/content/drive/My Drive/TB_classification_project/train/TB")
TB_xray[:5]
# Out:
# ['YTDRZTYG.png',
#  'JRRCQBLN.png',
#  'PDYNDHAU.png',
#  'QMTMVASN.png',
#  'OQGIGAUE.png']

# %%
tuberculosis_data= "/content/drive/My Drive/TB_classification_project/train_processed/TB/"
print("tuberculosis images :\n" ,os.listdir(tuberculosis_data)[:5])

normal_data= "/content/drive/My Drive/TB_classification_project/train_processed/normal"
print("\nnormal images :\n" ,os.listdir(normal_data)[:5])
# Out:
# tuberculosis images :
#  ['EHCFZYTF.png', 'VNVZJKOJ.png', 'BFUUQQNO.png', 'ZUQGJAOP.png', 'YPORVRYN.png']
#
# normal images :
#  ['EHCFZYTF.png', 'VNVZJKOJ.png', 'BFUUQQNO.png', 'ZUQGJAOP.png', 'YPORVRYN.png']

# %%
print("no. of tuberculosis images :" ,len(os.listdir(tuberculosis_data)))
print("\nno. of normal images :" ,len(os.listdir(normal_data)))
# Out:
# no. of tuberculosis images : 353
#
# no. of normal images : 365

# %%
# generating training data
print("training data :")
train_datagen= ImageDataGenerator(rescale=1/255, zoom_range=0.2,  width_shift_range= 0.2, height_shift_range=0.2, shear_range=0.2, 
                                   horizontal_flip=True,  validation_split = 0.2)

train_data = train_datagen.flow_from_directory(base_dir, 
                                              target_size= (224,224),
                                              class_mode= "binary",
                                              batch_size=32,
                                              subset= "training"
                                              )

# genarating validation data
print("\nvalidation data :")
val_datagen= ImageDataGenerator(rescale= 1/255, validation_split= 0.2)

val_data= train_datagen.flow_from_directory(base_dir, 
                                              target_size= (224,224),
                                              class_mode= "binary",
                                              batch_size=32,
                                              shuffle= False,
                                              subset= "validation"
                                              )
# Out:
# training data :
# Found 575 images belonging to 2 classes.
#
# validation data :
# Found 143 images belonging to 2 classes.

# %%
# Building our model model 
from tensorflow.keras.layers import BatchNormalization
from keras.layers import Dropout
model = models.Sequential()
model.add(layers.Conv2D(16, (3, 3), activation='relu',input_shape=(224,224,3))) #firstlayer
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(32, (3, 3), activation='relu',input_shape=(224,224,3))) #firstlayer
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(32, (6, 6), activation='relu',input_shape=(224,6224,3))) #firstlayer
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (6, 6), activation='relu',padding="same",input_shape=(224,224,3))) #secondlayer
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Flatten())


model.add(Dense(units = 64, kernel_initializer = 'uniform', activation = 'relu', input_dim = 224)) 
model.add(Dense(units = 32, kernel_initializer = 'uniform', activation = 'relu'))
model.add(Dense(units = 16, kernel_initializer = 'uniform', activation = 'relu'))
model.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_16 (Conv2D)           (None, 222, 222, 16)      448
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 111, 111, 16)      0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 109, 109, 32)      4640
# _________________________________________________________________
# max_pooling2d_17 (MaxPooling (None, 54, 54, 32)        0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 49, 49, 32)        36896
# _________________________________________________________________
# max_pooling2d_18 (MaxPooling (None, 24, 24, 32)        0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 24, 24, 64)        73792
# ...

# %%
history = model.fit(train_data, validation_data=val_data, epochs=20)
# Out:
# Epoch 1/20
# 58/58 [==============================] - 325s 6s/step - loss: 0.6938 - accuracy: 0.4800 - val_loss: 0.6931 - val_accuracy: 0.5105
# Epoch 2/20
# 58/58 [==============================] - 350s 6s/step - loss: 0.6932 - accuracy: 0.5078 - val_loss: 0.6931 - val_accuracy: 0.5105
# Epoch 3/20
# 58/58 [==============================] - 342s 6s/step - loss: 0.6922 - accuracy: 0.5078 - val_loss: 0.6847 - val_accuracy: 0.5105
# Epoch 4/20
# 58/58 [==============================] - 351s 6s/step - loss: 0.6710 - accuracy: 0.5896 - val_loss: 0.6871 - val_accuracy: 0.6084
# Epoch 5/20
# 58/58 [==============================] - 349s 6s/step - loss: 0.6637 - accuracy: 0.5983 - val_loss: 0.6892 - val_accuracy: 0.5105
# Epoch 6/20
# 58/58 [==============================] - 345s 6s/step - loss: 0.6623 - accuracy: 0.6400 - val_loss: 0.6699 - val_accuracy: 0.6154
# Epoch 7/20
# ...

# %%
prediction= model.predict(val_data, steps=np.ceil(val_data.samples/val_data.batch_size), verbose=2)
prediction= (prediction > 0.5)
#prediction
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-bbe34bc5da8e> in <module>()
# ----> 1 prediction= model.predict(val_data, steps=np.ceil(val_data.samples/val_data.batch_size), verbose=2)
#       2 prediction= (prediction > 0.5)
#       3 #prediction
#
# NameError: name 'model' is not defined

# %%
val_labels=val_data.classes
#val_labels

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from mlxtend.plotting import plot_confusion_matrix
cm= confusion_matrix(val_data.classes, prediction)
plot_confusion_matrix(cm, figsize=(5,5))

# %%
print(accuracy_score(val_data.classes, prediction))
print(classification_report(val_data.classes, prediction))

# %%
# evaluate the model
_, train_acc = model.evaluate(trainX, trainy, verbose=0)
_, test_acc = model.evaluate(testX, testy, verbose=0)
print('Train: %.3f, Test: %.3f' % (train_acc, test_acc))
# plot training history
pyplot.plot(history.history['accuracy'], label='train')
pyplot.plot(history.history['val_accuracy'], label='test')
pyplot.legend()
pyplot.show()
